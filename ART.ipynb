# %%
pwd
# Out:
# 'C:\\Users\\Vishesh Raina\\Desktop\\Online Courses\\Kaggle'

# %%
import pandas as pd
#import quandl, math, datetime
import numpy as np
from sklearn import preprocessing,  svm
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
import os
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from matplotlib import style

# %%
data=pd.read_csv("train.csv")

# %%
data.head(7)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
""""for col in data.columns:
    print (col, ':' ,len(data[col].unique()) ,' unique labels exist in this column')"""
# Out:
# '"for col in data.columns:\n    print (col, \':\' ,len(data[col].unique()) ,\' unique labels exist in this column\')'

# %%
data['MoSold']
# Out:
# 0        2
# 1        5
# 2        9
# 3        2
# 4       12
#         ..
# 1455     8
# 1456     2
# 1457     5
# 1458     4
# 1459     6
# Name: MoSold, Length: 1460, dtype: int64

# %%
data=data.drop(['Id','Street','Alley','Utilities','PoolQC','Fence','MiscFeature','PoolArea','MasVnrType'],axis=1)
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# 0          60       RL         65.0     8450      Reg         Lvl    Inside
# 1          20       RL         80.0     9600      Reg         Lvl       FR2
# 2          60       RL         68.0    11250      IR1         Lvl    Inside
# 3          70       RL         60.0     9550      IR1         Lvl    Corner
# 4          60       RL         84.0    14260      IR1         Lvl       FR2
#
#   LandSlope Neighborhood Condition1  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# 0       Gtl      CollgCr       Norm  ...          61             0         0
# 1       Gtl      Veenker      Feedr  ...           0             0         0
# 2       Gtl      CollgCr       Norm  ...          42             0         0
# 3       Gtl      Crawfor       Norm  ...          35           272         0
# 4       Gtl      NoRidge       Norm  ...          84             0         0
#
# ...

# %%
le = preprocessing.LabelEncoder()
encoded_labels=le.fit_transform(data["Neighborhood"])
encoded_labels
data=data.drop(["Neighborhood"],axis=1)
data["Neighborhood"]=encoded_labels
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LotShape LandContour LotConfig  \
# 0          60       RL         65.0     8450      Reg         Lvl    Inside
# 1          20       RL         80.0     9600      Reg         Lvl       FR2
# 2          60       RL         68.0    11250      IR1         Lvl    Inside
# 3          70       RL         60.0     9550      IR1         Lvl    Corner
# 4          60       RL         84.0    14260      IR1         Lvl       FR2
#
#   LandSlope Condition1 Condition2  ... EnclosedPorch 3SsnPorch  ScreenPorch  \
# 0       Gtl       Norm       Norm  ...             0         0            0
# 1       Gtl      Feedr       Norm  ...             0         0            0
# 2       Gtl       Norm       Norm  ...             0         0            0
# 3       Gtl       Norm       Norm  ...           272         0            0
# 4       Gtl       Norm       Norm  ...             0         0            0
#
# ...

# %%
encoded_labels=le.fit_transform(data["LotShape"])
encoded_labels
data=data.drop(["LotShape"],axis=1)
data["LotShape"]=encoded_labels
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LandContour LotConfig LandSlope  \
# 0          60       RL         65.0     8450         Lvl    Inside       Gtl
# 1          20       RL         80.0     9600         Lvl       FR2       Gtl
# 2          60       RL         68.0    11250         Lvl    Inside       Gtl
# 3          70       RL         60.0     9550         Lvl    Corner       Gtl
# 4          60       RL         84.0    14260         Lvl       FR2       Gtl
#
#   Condition1 Condition2 BldgType  ... 3SsnPorch  ScreenPorch  MiscVal  MoSold  \
# 0       Norm       Norm     1Fam  ...         0            0        0       2
# 1      Feedr       Norm     1Fam  ...         0            0        0       5
# 2       Norm       Norm     1Fam  ...         0            0        0       9
# 3       Norm       Norm     1Fam  ...         0            0        0       2
# 4       Norm       Norm     1Fam  ...         0            0        0      12
#
# ...

# %%
### Function to determine if an object within the data frame is an integer or not
def is_integer(n):
    try:
        float(n)
    except ValueError:
        return False
    else:
        return float(n).is_integer()

# %%
#print(is_integer(data["LotFrontage"][4]))
#print(is_integer(data["LotConfig"][2]))
is_integer(data["LotConfig"][4])
# Out:
# False

# %%
dataT=data.T
dataT.shape
# Out:
# (72, 1460)

# %%
data["LotArea"][3]
# Out:
# 9550

# %%
data=data.interpolate(method='quadratic')
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea LandContour LotConfig LandSlope  \
# 0          60       RL         65.0     8450         Lvl    Inside       Gtl
# 1          20       RL         80.0     9600         Lvl       FR2       Gtl
# 2          60       RL         68.0    11250         Lvl    Inside       Gtl
# 3          70       RL         60.0     9550         Lvl    Corner       Gtl
# 4          60       RL         84.0    14260         Lvl       FR2       Gtl
#
#   Condition1 Condition2 BldgType  ... 3SsnPorch  ScreenPorch  MiscVal  MoSold  \
# 0       Norm       Norm     1Fam  ...         0            0        0       2
# 1      Feedr       Norm     1Fam  ...         0            0        0       5
# 2       Norm       Norm     1Fam  ...         0            0        0       9
# 3       Norm       Norm     1Fam  ...         0            0        0       2
# 4       Norm       Norm     1Fam  ...         0            0        0      12
#
# ...

# %%
#List of items to be encoded (yes, it is unprofessional & rookie)
to_be_encoded=["MSZoning","LotShape","LandContour","LotConfig","LandSlope","Condition1",
                   "Condition2","BldgType","HouseStyle","RoofStyle","RoofMatl","Exterior1st","Exterior2nd","ExterQual",
                   "ExterCond","Foundation","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","BsmtFinType2", 
                   "Heating","HeatingQC","CentralAir","Electrical","KitchenQual","Functional", "FireplaceQu","GarageType",
                    "GarageFinish", "GarageQual","GarageCond","PavedDrive","SaleType","SaleCondition"]
print(data[to_be_encoded[2]])            #It's legit
len(to_be_encoded)
# Out:
# 0       Lvl
# 1       Lvl
# 2       Lvl
# 3       Lvl
# 4       Lvl
#        ...
# 1455    Lvl
# 1456    Lvl
# 1457    Lvl
# 1458    Lvl
# 1459    Lvl
# Name: LandContour, Length: 1460, dtype: object
# 35

# %%
for i in range(35):
    print(data[to_be_encoded[i]])
    data[to_be_encoded[i]] = pd.to_numeric(data[to_be_encoded[i]], errors='coerce')
    #encoded_labels=data[to_be_encoded[i]].apply(lambda col: le.fit_transform(col.astype(str)))
    encoded_labels=le.fit_transform(data[to_be_encoded[i]])
    encoded_labels
    data=data.drop([to_be_encoded[i]],axis=1)
    data[to_be_encoded[i]]=encoded_labels
# Out:
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object
# 0       3
# 1       3
# 2       0
# 3       0
# 4       0
#        ..
# 1455    3
# 1456    3
# 1457    3
# 1458    3
# 1459    3
# Name: LotShape, Length: 1460, dtype: int32
# 0       Lvl
# 1       Lvl
# 2       Lvl
# 3       Lvl
# 4       Lvl
#        ...
# 1455    Lvl
# 1456    Lvl
# 1457    Lvl
# 1458    Lvl
# 1459    Lvl
# Name: LandContour, Length: 1460, dtype: object
# 0       Inside
# 1          FR2
# 2       Inside
# 3       Corner
# 4          FR2
#          ...
# 1455    Inside
# 1456    Inside
# 1457    Inside
# 1458    Inside
# 1459    Inside
# Name: LotConfig, Length: 1460, dtype: object
# 0       Gtl
# 1       Gtl
# 2       Gtl
# 3       Gtl
# 4       Gtl
#        ...
# 1455    Gtl
# 1456    Gtl
# 1457    Gtl
# 1458    Gtl
# 1459    Gtl
# Name: LandSlope, Length: 1460, dtype: object
# ...

# %%
""" 
#data_encoded = data.apply(LabelEncoder.fit_transform)
#data_encoded[:,0]=le.fit_transform(data[:,0])
from sklearn.preprocessing import OneHotEncoder
oh=OneHotEncoder()

data_encoded=oh.fit_transform(data).toarray()
print(data_encoded) """
# Out:
# ' \n#data_encoded = data.apply(LabelEncoder.fit_transform)\n#data_encoded[:,0]=le.fit_transform(data[:,0])\nfrom sklearn.preprocessing import OneHotEncoder\noh=OneHotEncoder()\n\ndata_encoded=oh.fit_transform(data).toarray()\nprint(data_encoded) '

# %%
data.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  KitchenQual  \
# 0          2003       196.0         706           0  ...            0
# 1          1976         0.0         978           0  ...          976
# 2          2002       162.0         486           0  ...          975
# 3          1970         0.0         216           0  ...          974
# 4          2000       350.0         655           0  ...          973
#
#    Functional  FireplaceQu  GarageType  GarageFinish  GarageQual  GarageCond  \
# ...

# %%
X=data.drop(["SalePrice"],axis=1)

print(X.shape)
# Out:
# (1460, 71)
